# %% [markdown]
# # Day 7 - Tuples
#
# ## 120 Days of Machine Learning
#
# Learn:
# - Tuple Basics
# - Accessing Elements
# - Slicing
# - Packing
# - Unpacking
# - Tuple Methods
# - Built-in Functions
# - Tuple vs List

# %%
numbers = (10,20,30,40,50)

numbers
# Out:
# (10, 20, 30, 40, 50)

# %%
numbers[0], numbers[-1]
# Out:
# (10, 50)

# %%
numbers[1:4]
# Out:
# (20, 30, 40)

# %%
numbers[::-1]
# Out:
# (50, 40, 30, 20, 10)

# %%
for i in numbers:
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
person = ("Athiya",22,"Engineer")

name, age, profession = person

print(name)
print(age)
print(profession)
# Out:
# Athiya
# 22
# Engineer

# %%
values = (2,5,8,2,9,2)

print(values.count(2))
print(values.index(9))
# Out:
# 3
# 4

# %%
values = (4,7,1,8)

print(min(values))
print(max(values))
print(sum(values))
print(sorted(values))
# Out:
# 1
# 8
# 20
# [1, 4, 7, 8]

# %%
tuple([1,2,3]), list((4,5,6))
# Out:
# ((1, 2, 3), [4, 5, 6])

# %%
coordinates = (12.9716, 77.5946)

print("Latitude:", coordinates[0])
print("Longitude:", coordinates[1])
# Out:
# Latitude: 12.9716
# Longitude: 77.5946

# %% [markdown]
# # Practice Exercises
#
# 1. Create a tuple of 10 numbers.
# 2. Find the maximum value.
# 3. Count how many times 5 appears.
# 4. Reverse the tuple.
# 5. Convert the tuple to a list.
# 6. Convert the list back to a tuple.
# 7. Create a nested tuple and access an inner element.
# 8. Perform tuple unpacking.
# 9. Check membership using `in`.
# 10. Try modifying a tuple and observe the error.
