# %% [markdown]
# # Day 05 – Python Functions
#
# ## Objectives
#
# By the end of this notebook, you will be able to:
#
# - Understand what functions are
# - Create user-defined functions
# - Pass arguments to functions
# - Return values from functions
# - Use default, keyword, and variable-length arguments
# - Understand local and global scope
# - Create lambda functions
# - Write recursive functions

# %% [markdown]
# ## What is a Function?
#
# A function is a reusable block of code designed to perform a specific task. Functions help organize code, reduce repetition, and improve readability.

# %%
def greet():
    print("Welcome to Machine Learning!")

greet()
# Out:
# Welcome to Machine Learning!

# %% [markdown]
# ## Function with Parameters

# %%
def add(a, b):
    print("Sum =", a + b)

add(10, 20)
# Out:
# Sum = 30

# %% [markdown]
# ## Function with Return Statement

# %%
def square(number):
    return number ** 2

result = square(5)
print(result)
# Out:
# 25

# %% [markdown]
# ## Default Arguments

# %%
def greet(name="Guest"):
    print("Hello", name)

greet()
greet("Athiya")
# Out:
# Hello Guest
# Hello Athiya

# %% [markdown]
# ## Keyword Arguments

# %%
def student(name, age):
    print(name, age)

student(age=21, name="Athiya")
# Out:
# Athiya 21

# %% [markdown]
# ## Variable-Length Arguments (*args)

# %%
def total(*numbers):
    return sum(numbers)

print(total(5, 10, 15, 20))
# Out:
# 50

# %% [markdown]
# ## Keyword Variable-Length Arguments (**kwargs)

# %%
def details(**info):
    for key, value in info.items():
        print(key, ":", value)

details(name="Athiya", city="Mysuru", age=21)
# Out:
# name : Athiya
# city : Mysuru
# age : 21

# %% [markdown]
# ## Local and Global Variables

# %%
x = 100

def demo():
    x = 50
    print("Local:", x)

demo()
print("Global:", x)
# Out:
# Local: 50
# Global: 100

# %% [markdown]
# ## Lambda Functions

# %%
square = lambda x: x * x

print(square(8))
# Out:
# 64

# %% [markdown]
# ## Recursive Functions

# %%
def factorial(n):
    if n == 1:
        return 1
    return n * factorial(n - 1)

print(factorial(5))
# Out:
# 120

# %% [markdown]
# ## Real-World Example
#
# Functions are commonly used to:
# - Calculate salaries
# - Validate login credentials
# - Process payments
# - Analyze datasets
# - Build Machine Learning pipelines

# %%
def calculate_average(marks):
    return sum(marks) / len(marks)

scores = [78, 85, 90, 88, 92]

print("Average Score:", calculate_average(scores))
# Out:
# Average Score: 86.6

# %% [markdown]
# ## Practice Exercises
#
# Try these on your own:
#
# 1. Create a function to find the largest of three numbers.
# 2. Create a function to check if a number is even or odd.
# 3. Create a function to calculate the area of a circle.
# 4. Write a recursive function for Fibonacci numbers.
# 5. Create a lambda function to cube a number.

# %% [markdown]
# ## Mini Challenge
#
# Build a simple calculator using functions.
#
# Requirements:
#
# - Addition
# - Subtraction
# - Multiplication
# - Division
# - User input

# %%
def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    return a / b

print("Addition:", add(20, 10))
print("Subtraction:", subtract(20, 10))
print("Multiplication:", multiply(20, 10))
print("Division:", divide(20, 10))
# Out:
# Addition: 30
# Subtraction: 10
# Multiplication: 200
# Division: 2.0

# %% [markdown]
# # Summary
#
# Today you learned:
#
# - What functions are
# - User-defined functions
# - Parameters and arguments
# - Return statements
# - Default arguments
# - Keyword arguments
# - *args and **kwargs
# - Local and global variables
# - Lambda functions
# - Recursion
#
# Next Topic: **Lists**
